# %%
import molsysmt as msm

# %%
msm.convert('1tcd')
# Out:
# 1
# Failing with 'dataBlocks'
# Traceback (most recent call last):
#   File "/home/diego/Myopt/miniconda3/envs/molsysviewer@uibcdf_3.12/lib/python3.12/site-packages/mmcif/io/BinaryCifReader.py", line 79, in __deserialize
#     logger.debug("bD['dataBlocks'] %s", bD[self.__toBytes("dataBlocks")])
#                                         ~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'dataBlocks'
# 2
# Failing with 'dataBlocks'
# Traceback (most recent call last):
#   File "/home/diego/repos@uibcdf/molsysmt/molsysmt/form/string_pdb_id/to_mmcif_PdbxContainers_DataContainer.py", line 16, in to_mmcif_PdbxContainers_DataContainer
#     tmp_item = file_bcif_gz_to_mmcif_PdbxContainers_DataContainer(tmp_item, skip_digestion=True)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/diego/repos@uibcdf/molsysmt/molsysmt/_private/digestion/digest.py", line 52, in wrapper
#     return func(*args, **kwargs)
# ...
