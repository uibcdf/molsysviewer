# %%
import molsysmt as msm
import molsysviewer as viewer

# %%
molsys = msm.systems['pentalanine']['traj_pentalanine.h5']
v = viewer.load(molsys)

# %%
v.set_controls_visible(True, autohide=True)

# %%
v.show()
