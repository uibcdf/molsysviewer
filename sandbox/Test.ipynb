# %%
import molsysmt as msm
import molsysviewer as viewer

# %%
view = viewer.demo.tctim

# %%
view.global_view.hide()

# %%
view.show()

# %%
region1 = view.new_region("chain_id == 'A'", representation="sticks")

# %%
region2 = view.new_region("chain_id == 'B'", representation="cartoon")

# %%
region2.hide()

# %%
region2.show()

# %%
view.shapes.add_sphere(center=[0,0,0], radius=5, color=0xFF0000, alpha=0.5, tag="test-sphere")

# %%
view.layers["test-sphere"].hide()

# %%
view.layers["test-sphere"].show()

# %%
view.hide()

# %%
view.show()

# %%
view.global_view.hide()

# %%
view.regions
# Out:
# {'region1': <molsysviewer.regions.Region at 0x7c1abc0a1fa0>,
#  'region2': <molsysviewer.regions.Region at 0x7c1a14f88c80>}

# %%
view.layers
# Out:
# {'test-sphere': <molsysviewer.layers.Layer at 0x7c1a0e46e540>}
