# %%
import molsysviewer as msv

# %%
view = msv.new_view("2NZT", viewer_mode="integrated", height="500px")

# %%
view

# %%
view.whole.show()

# %%
r = view.new_region("chain_index==0", tag="chain 0")

# %%
r.set_representation("inherit")

# %%
r.set_representation("spacefill")

# %%
r2 = view.new_region("chain_index==1", tag="chain 1")

# %%
r2.set_representation("spacefill", alpha=0.1)

# %%
r.hide()

# %%
view.whole.hide()
r = view.new_region("chain_index==0", tag="sel")
r.set_representation("inherit")
view.whole.show()

# %%
r2.set_representation("inherit")

# %%
_ = msv.addon_templates.register_dummy_addon()

# %%
view = msv.new_view()

# %%
view

# %%
# 1CRN, 1L2Y
# 1LE5, 1IKN, 1NFI

# %%
msv.new_view()
