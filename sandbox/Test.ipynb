# %%
import molsysmt as msm

# %%
molsys = msm.convert('../molsysviewer/data/h5msm/traj_pentalanine.h5msm')

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd2c7">
#   <thead>
#     <tr>
#       <th id="T_fd2c7_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_fd2c7_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_fd2c7_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_fd2c7_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_fd2c7_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_fd2c7_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_fd2c7_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_fd2c7_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_fd2c7_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fd2c7_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
# ...
