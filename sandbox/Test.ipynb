# %%
import molsysviewer as msv

# %%
view = msv.new_view("1L2Y", viewer_mode="integrated", height="400px")

# %%
view

# %%
print("Ancho:", view.widget.layout.width)
print("Alto:", view.widget.layout.height)
print("Alto Mínimo:", view.widget.layout.min_height)

# %%
# 1CRN, 1L2Y
