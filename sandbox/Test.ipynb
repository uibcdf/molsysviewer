# %%
import molsysmt as msm

# %%
molsys = msm.convert('181L')

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7cdc6">
#   <thead>
#     <tr>
#       <th id="T_7cdc6_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_7cdc6_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_7cdc6_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_7cdc6_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_7cdc6_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_7cdc6_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_7cdc6_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_7cdc6_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_7cdc6_level0_col8" class="col_heading level0 col8" >n_ions</th>
#       <th id="T_7cdc6_level0_col9" class="col_heading level0 col9" >n_small_molecules</th>
# ...

# %%
msm.convert(molsys, '181L.h5msm')
# Out:
# '181L.h5msm'
