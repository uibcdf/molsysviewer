# %%
from molsysviewer import MolSysViewer

# %%
view = MolSysViewer.from_empty()

# %%
view.show_test_sphere(
    center=[0.0, 0.0, 0.0],
    radius=5.0,
    color=[0.8, 0.2, 0.2],  # rojo suave
    opacity=0.4,
)

# %%
view.show()
# Out:
# MolSysViewerWidget()
# MolSysViewerWidget()
