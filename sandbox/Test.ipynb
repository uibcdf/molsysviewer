# %%
import molsysviewer as viewer
# Out:
# Traceback (most recent call last):
#
#   File ~/Myopt/miniconda3/envs/molsysviewer@uibcdf_3.12/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     import molsysviewer as viewer
#
#   File ~/repos@uibcdf/molsysviewer/molsysviewer/__init__.py:3
#     from .viewer import MolSysView
#
#   File ~/repos@uibcdf/molsysviewer/molsysviewer/viewer.py:10
#     import molsysmt as msm
#
#   File ~/repos@uibcdf/molsysmt/molsysmt/__init__.py:32
#     from . import form
#
#   File ~/repos@uibcdf/molsysmt/molsysmt/form/__init__.py:5
#     from molsysmt.dependencies import is_installed
#
#   File ~/repos@uibcdf/molsysmt/molsysmt/dependencies.py:6
#     from molsysmt.config.dependencies import dependencies as _dependencies_config
#
#   File ~/repos@uibcdf/molsysmt/molsysmt/config/dependencies.py:19
#     ...
#       ^
# SyntaxError: ':' expected after dictionary key

# %%
view = viewer.MolSysView()
view.load('1BRS')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 view = viewer.MolSysView()
#       2 view.load('1BRS')
#
# NameError: name 'viewer' is not defined

# %%
view.show()
