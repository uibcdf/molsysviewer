# %%
import molsysmt as msm
import molsysviewer as msv

# %%
molsys = msm.convert('1TCD', selection='molecule_type=="protein"')

# %%
view = msv.MolSysView()

# %%
view.load(molsys)

# %%
view

# %%
view.styles.
