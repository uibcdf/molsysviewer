# %%
from molsysviewer import MolSysView                                                                                                                  
from molsysviewer.demo import demo

# %%
view = demo["dialanine"]
view

# %%
view = MolSysView(controls_mode="minimal")                
view.load(demo["dialanine"]._molsys)                                                                                                                                       
view
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 view = MolSysView(controls_mode="minimal")
#       2 view.load(demo["dialanine"]._molsys)
#       3 view
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# ...

# %%
view = MolSysView(panel_mode_style="floating")            
view.load(demo["dialanine"]._molsys)          
view

# %%
view = MolSysView(controls_mode="minimal", panel_mode_style="floating")
view.load(demo["dialanine"]._molsys)                                                                                                                                       
view

# %%
from molsysviewer import MolSysView, config               
from molsysviewer.demo import demo                                                                                                                                         
                                                            
config.controls_mode = "minimal"
                                  
view = MolSysView()
view.load(demo["dialanine"]._molsys)                                                                                                                                       
view
