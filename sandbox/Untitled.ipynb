# %%
import molsysmt as msm

# %%
msm.basic.are_multiple_molecular_systems(['1CRN', '2LAO'])
# Out:
# True

# %%
msm.basic.is_a_molecular_system(['1CRN', '2LAO'])
# Out:
# False

# %%
msm.get_form(['1CRN', '2LAO'])
# Out:
# ['string:pdb_id', 'string:pdb_id']

# %%
molsys = msm.convert(['1CRN', '2LAO'])
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 molsys = msm.convert(['1CRN', '2LAO'])
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:137, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     130     warnings.warn(
#     131         f"SMonitor signal push_frame failed for {fn.__module__}.{fn.__name__}: {exc}",
#     132         RuntimeWarning,
#     133         stacklevel=2,
#     134     )
#     136 try:
# --> 137     return fn(*args, **kwargs)
#     138 except Exception as exc:
#     139     try:
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:137, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     130     warnings.warn(
#     131         f"SMonitor signal push_frame failed for {fn.__module__}.{fn.__name__}: {exc}",
#     132         RuntimeWarning,
#     133         stacklevel=2,
# ...
