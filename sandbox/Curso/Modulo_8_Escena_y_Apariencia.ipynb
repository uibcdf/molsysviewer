# %% [markdown]
# Módulo 8: El Escenario Molecular (Escena y Apariencia Global)
#
# el alumno aprenderá que el contexto visual es tan importante como la molécula misma.
#
#   Objetivos Pedagógicos:
#    1. Personalizar el color de fondo (Background).
#    2. Controlar la iluminación global.
#    3. Añadir profundidad con la niebla (Fog).
#    4. Activar la rotación automática (Spin).

# %%
import molsysviewer as msv
view = msv.MolSysView()
view.load('1CRN')

# %%
view

# %%
view.scene.set_background(color='blue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 view.scene.set_background(color='blue')
#
# TypeError: SceneManager.set_background() got an unexpected keyword argument 'color'

# %%
view.scene.swing(False)

# %%
help(view.scene.swing)
# Out:
# Help on method swing in module molsysviewer.scene:
#
# swing(enabled: 'bool' = True, speed: 'float | None' = None) -> 'None' method of molsysviewer.scene.SceneManager instance
#     Enable or disable oscillating rock motion.
#
#     Parameters
#     ----------
#     enabled
#         ``True`` to start swinging, ``False`` to stop.
#     speed
#         Oscillation speed (Mol* units; default ~0.25). Ignored when *enabled* is ``False``.
