# %% [markdown]
# Módulo 1: Carga e Identidad (Cimientos)
#
#   En este primer capítulo, enseñaremos al usuario a traer sus moléculas al mundo virtual y cómo MolSysViewer gestiona la "identidad" de lo que cargamos.
#
#   Objetivos Pedagógicos:
#    1. Instanciar el visor.
#    2. Cargar una estructura desde un PDB ID.
#    3. Entender el concepto de label para organizar múltiples cargas.
#    4. Inspeccionar el sistema molecular subyacente.

# %%
import molsysviewer as msv

# %%
view = msv.MolSysView()

# %%
view.load('1TCD', label='1tcd')

# %%
view

# %%
view.molsys.info()

# %%
view.info()

# %% [markdown]
# - view.info() debe dar la info del viewer
# - un segundo load hace una segunda carga sobre la original parecido a si hicieramos view.add()

# %%
view.regions

# %%
view.load('1CRN', label='1crn')

# %%
view.regions

# %%
view.load('2LAO', label='2lao')

# %%
view.regions

# %%
print(f"Número de bloques registrados: {len(view._load_blocks)}")
for i, block in enumerate(view._load_blocks):
    print(f"Bloque {i}: {block}")

# %%
print(f"Regiones en Python: {list(view.regions.keys())}")
