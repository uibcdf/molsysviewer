# %% [markdown]
# Precisión Científica (Medidas de Distancias y Ángulos)
#
# Módulo 5: Precisión Científica (Medidas de Distancias y Ángulos)
#
#   Objetivos Pedagógicos:
#    1. Realizar medidas de distancia interactivas.
#    2. Entender el concepto de Persistencia (capturar medidas del visor a Python).
#    3. Consultar valores numéricos de las medidas para análisis posterior.

# %%
import molsysviewer as msv
view = msv.MolSysView()
view.load('1CRN')
view

# %%
# --- INSTRUCCIONES PARA EL ALUMNO ---
# 1. Haz clic derecho sobre un átomo y selecciona "Distance".
# 2. Haz clic en un segundo átomo para completar la medida.
# 3. Una vez veas la línea punteada con el valor en Å, ejecuta la celda de abajo.

# %%
info = view.measurements.info()

# %%
info
# Out:
# []

# %%
distancia = info[0].get('value')
print(f"La distancia medida es: {distancia} Å")

# %%
info[0]

# %%
view.measurements['measurement_1'].delete()

# %%
view.measurements['measurement_1'].focus()

# %%
angulo = view.measurements.add_angle(atom_indices_a=[10], atom_indices_b=[11], atom_indices_c=[12], tag='mi_angulo')

# %%
view.measurements['mi_angulo'].focus()

# %%
view.measurements['mi_angulo'].delete()
