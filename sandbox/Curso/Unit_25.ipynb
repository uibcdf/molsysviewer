# %% [markdown]
# # Unit 25: Add-on Infrastructure
#
# Enabling and interfacing with scientific plugins.
#
# ### Learning Objectives
# 1. Discover registered add-ons.
# 2. Enable specialized add-on namespaces.
# 3. Trigger high-level context actions.

# %% [markdown]
# ## 1. Setting the Stage: Discovering Add-ons
#
# We list all available scientific plugins.

# %%
import molsysviewer as msv

print("Available Add-ons:", msv.addons.available())

# %% [markdown]
# ## 2. Enabling Add-ons
#
# We can enable plugins (like elasnetmt) on our viewer instance.

# %%
view = msv.MolSysView()
view.load('1CRN', label='crambin')
# view.addons.enable('elasnetmt')
