# %% [markdown]
# # Smoke Test 2

# %%
from molsysviewer import demo

# %%
view = demo["1TCD"]

# %%
view

# %%
view = demo["dialanine"]

# %%
view

# %%
view.annotations.tags()

# %%
view.annotations.count()

# %%
view.annotations.info()

# %%
view.annotations.set_text("layer1", "Edited")

# %%
view.annotations.set_group_index("layer1", 1)

# %%
view.annotations.hide("layer1")

# %%
view.annotations.show("layer1")

# %%
view._build_export_messages()
