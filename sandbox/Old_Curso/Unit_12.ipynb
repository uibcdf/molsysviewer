# %% [markdown]
# # Unit 12: Trajectories & Structure Navigation
#
# Molecular systems are rarely static. Whether you are analyzing a Molecular Dynamics (MD) trajectory or comparing docking poses, you need to navigate through frames. In this unit, we will use a real MD snippet to master the **Player Manager** and control the structural timeline.
#
# ### Learning Objectives
# 1. Load a trajectory from the **Demo Catalog**.
# 2. Navigate through structures using the `view.player` manager.
# 3. Control playback speed, direction, and looping.
# 4. Query the current structural state programmatically.

# %% [markdown]
# ## 1. Setting the Stage
#
# We will load a pentalanine trajectory from the built-in demo catalog. This system contains 200 frames of a small peptide in motion.

# %%
import molsysviewer as msv

# Load a real trajectory demo
view = msv.demo['pentalanine']

# Display the viewer with its trajectory player
view

# %% [markdown]
# ## 2. Programmatic Navigation
#
# The `view.player` manager allows you to jump to specific points in the trajectory. This is vital for linking structural visualization to analytical events (e.g., "Jump to the folding event").

# %%
# Jump to the 50th frame (index 49)
view.player.go_to_structure(index=49)

# Inspect the current state
print(f"Current frame index: {view.player.index}")
print(f"Total frames available: {view.player.n_structures}")
# Out:
# Current frame index: 49
# Total frames available: 200

# %% [markdown]
# ## 3. Controlling the Animation
#
# You can start, pause, and adjust the playback speed (FPS) directly from Python. You can also change the direction or set the player to 'loop' or 'ping-pong' mode.

# %%
# Play the trajectory at 24 frames per second
view.player.play(fps=24)
# Out:
# WARNING: /home/diego/repos@uibcdf/argdigest/argdigest/core/decorator.py:253: DigestNotDigestedWarning: No digester for fps Define or register a digester for 'fps'. Docs: https://www.uibcdf.com/argdigest
#   warnings.warn(
#
# ERROR:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Play the trajectory at 24 frames per second
# ----> 2 view.player.play(fps=24)
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:354, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     352     with puw_ctx_manager(**effective_puw_context):
#     353         return _run_digestion()
# --> 354 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:313, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     311     for argname in bound:
#     312         if argname != "self":
# --> 313             gut(argname)
#     314     bound.update(digested)
#     315 for argname, cfg_pipe in plan.pipeline_targets.items():
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:299, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion.<locals>.gut(argname)
#     297     if hasattr(e, 'message'): # Some custom errors might have message
#     298          raise e
# --> 299     raise e
#     301 visiting_path.pop()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:281, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion.<locals>.gut(argname)
#     278         kwargs_for_digest[p_name] = None
#     280 try:
# --> 281     digested[argname] = fn_digest(**kwargs_for_digest)
#     282 except Exception as e:
#     283     # Centralized observability: report to smonitor
#     284     try:
#
# File ~/repos@uibcdf/molsysviewer/molsysviewer/_private/argdigest/argument/mode.py:32, in digest_mode(mode, caller)
#      29         if mode in ["perspective", "orthographic"]:
#      30             return mode
# ---> 32 raise ArgumentError('mode', value=mode, caller=caller, message=None)
#
# ArgumentError: Error in molsysviewer.player.play due to the mode argument with value None.

# %%
# Change direction to backward
view.player.set_direction('backward')

# Pause the animation
# view.player.pause()
# Out:
# ERROR:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Change direction to backward
# ----> 2 view.player.set_direction('backward')
#       4 # Pause the animation
#       5 # view.player.pause()
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# File ~/repos@uibcdf/smonitor/smonitor/core/decorator.py:59, in signal.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      57 push_frame(frame)
#      58 try:
# ---> 59     return fn(*args, **kwargs)
#      60 except Exception as exc:
#      61     # Capture args summary on error if not already captured
#      62     if frame.args is None:
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:354, in arg_digest.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#     352     with puw_ctx_manager(**effective_puw_context):
#     353         return _run_digestion()
# --> 354 return _run_digestion()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:313, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion()
#     311     for argname in bound:
#     312         if argname != "self":
# --> 313             gut(argname)
#     314     bound.update(digested)
#     315 for argname, cfg_pipe in plan.pipeline_targets.items():
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:299, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion.<locals>.gut(argname)
#     297     if hasattr(e, 'message'): # Some custom errors might have message
#     298          raise e
# --> 299     raise e
#     301 visiting_path.pop()
#
# File ~/repos@uibcdf/argdigest/argdigest/core/decorator.py:281, in arg_digest.<locals>.deco.<locals>.wrapper.<locals>._run_digestion.<locals>.gut(argname)
#     278         kwargs_for_digest[p_name] = None
#     280 try:
# --> 281     digested[argname] = fn_digest(**kwargs_for_digest)
#     282 except Exception as e:
#     283     # Centralized observability: report to smonitor
#     284     try:
#
# File ~/repos@uibcdf/molsysviewer/molsysviewer/_private/argdigest/argument/direction.py:26, in digest_direction(direction, caller)
#      23             direction[ii] = direction[ii]/np.linalg.norm(direction[ii])
#      24         return direction
# ---> 26 raise ArgumentError('direction', value=direction, caller=caller, message=None)
#
# ArgumentError: Error in molsysviewer.player.set_direction due to the direction argument with value backward.

# %% [markdown]
# ## 4. Frame-by-Frame Inspection
#
# For detailed analysis, use the stepping methods. `step_forward()` and `step_backward()` allow you to advance the system by a specific number of frames.

# %%
# Advance by 5 frames
view.player.step_forward(n=5)

print(f"New frame: {view.player.index}")
# Out:
# WARNING: /home/diego/repos@uibcdf/argdigest/argdigest/core/decorator.py:253: DigestNotDigestedWarning: No digester for n Define or register a digester for 'n'. Docs: https://www.uibcdf.com/argdigest
#   warnings.warn(
# New frame: 54

# %% [markdown]
# ### Summary
# The Player Manager makes molecular dynamics accessible and reproducible.
# - Load trajectories directly via `msv.demo` or standard `load()`.
# - Navigate semantically with `go_to_structure()`.
# - Command the animation loop with `play()` and `set_fps()`.
#
# In the next unit, **Unit 13: Advanced Sectioning & Clipping**, we will learn how to slice through these moving systems to reveal their internal dynamics.
