# %% [markdown]
# # Sphinx HTML Embedding

# %%
import molsysviewer as viewer
from molsysviewer.loaders import load_pdb_id

# %%
view = load_pdb_id(pdb_id='1TCD')

# %%
view.show()

# %%
view.write_html(output_filename='embedding_test.html', title='Embedding Test')
