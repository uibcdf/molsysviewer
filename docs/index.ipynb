# %% [markdown]
# ```{eval-rst}
# :html_theme.sidebar_secondary.remove:
# ```

# %% [markdown]
# :::{figure} _static/logo.svg
# :width: 62%
# :align: center
#
# A Mol*-powered interactive **mol**ecular **sys**tems **viewer** for structural analysis
#
# ```{image} https://img.shields.io/badge/release-v0.1.0-white.svg
# :target: https://github.com/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/license-MIT-white.svg
# :target: https://github.com/uibcdf/molsysviewer/blob/master/LICENSE
# ```
# ```{image} https://img.shields.io/badge/install%20with-conda-white.svg
# :target: https://anaconda.org/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/python-3.10%20%7C%203.11%20%7C%203.12-white.svg
# :target: https://www.python.org/downloads/
# ```
# ```{image} https://img.shields.io/badge/DOI-10.5281/8092688-white.svg
# :target: https://zenodo.org/record/8092688
# ```
#
# :::
#
# <br/>
#
#
# ## Install it
#
# ```bash
# conda install -c uibcdf molsysviewer
# ```
#
# <br/>
#
# ## Use it

# %%
import molsysviewer as viewer

view = viewer.load('1TCD')
view.clean()
view.show(selection='all within 4.5 angstroms of atom_name=="CA" and residue_id=="23"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import molsysviewer as viewer
# ----> 3 view = viewer.load('1TCD')
#       4 view.clean()
#       5 view.show(selection='all within 4.5 angstroms of atom_name=="CA" and residue_id=="23"')
#
# File ~/repos@uibcdf/molsysviewer/molsysviewer/load.py:19, in load(molecular_system, selection, structure_indices, view)
#      11 def load(
#      12     molecular_system: Any,
#      13     selection: Selection = "all",
#      14     structure_indices: StructureIndices = "all",
#      15     view: MolSysView | None = None,
#      16 ) -> MolSysView:
#      18     view = MolSysView() if view is None else view
# ---> 19     view.load(
#      20         molecular_system,
#      21         selection=selection,
#      22         structure_indices=structure_indices,
#      23     )
#      24     return view
#
# File ~/repos@uibcdf/molsysviewer/molsysviewer/viewer.py:105, in MolSysView.load(self, molecular_system, selection, structure_indices, syntax, label)
#      96 def load(
#      97     self,
#      98     molecular_system: Any,
#    (...)    102     label: str | None = None,
#     103 ) -> None:
#     104     """Load a molecular system (MolSysMT-compatible) into the viewer."""
# --> 105     _load_from_molsysmt(
#     106         molecular_system=molecular_system,
#     107         selection=selection,
#     108         structure_indices=structure_indices,
#     109         syntax=syntax,
#     110         label=label,
#     111         view=self,
#     112     )
#
# File ~/repos@uibcdf/molsysviewer/molsysviewer/loaders/load_molsysmt.py:54, in load_from_molsysmt(molecular_system, selection, structure_indices, syntax, label, view)
#      51 n_atoms = view._molsys.get(element="atom", n_atoms=True)
#      52 view.atom_mask = np.ones(n_atoms, dtype=bool)
# ---> 54 viewer_json = view._molsys.to_form("molsysmt.ViewerJSON")
#      56 payload = {"atom_id": None,
#      57            "atom_name": None,
#      58            "residue_id": None,
#    (...)     64            "bonds": None,
#      65            "structures": None}
#      67 payload["atom_id"] = viewer_json.get("atoms").get("atom_id")
#
# File ~/repos@uibcdf/molsysmt/molsysmt/native/molsys.py:132, in MolSys.to_form(self, to_form, skip_digestion, **kwargs)
#     128 def to_form(self, to_form, skip_digestion=False, **kwargs):
#     130     from molsysmt.form.molsysmt_MolSys import _convert_to
# --> 132     return _convert_to[form](self, skip_digestion=True, **kwargs)
#
# NameError: name 'form' is not defined

# %%
view.info()

# %% [markdown]
# ## Citation
#
# Coming soon...

# %% [markdown]
# ```{eval-rst}
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/about/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/showcase/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/user/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/developer/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    api/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/ai_assistants.md
#
# ```
