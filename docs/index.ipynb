# %% [markdown]
# ```{eval-rst}
#  :html_theme.sidebar_secondary.remove:
# ```

# %% [markdown]
# :::{figure} _static/logo.svg
# :width: 55%
# :align: center
# MolSysViewer is a Mol*-powered interactive **mol**ecular **sys**tems **viewer** for structural analysis.
#
# ```{image} https://img.shields.io/badge/release-v0.1.0-white.svg
# :target: https://github.com/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/license-MIT-white.svg
# :target: https://github.com/uibcdf/molsysviewer/blob/master/LICENSE
# ```
# ```{image} https://img.shields.io/badge/install%20with-conda-white.svg
# :target: https://anaconda.org/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/python-3.10%20%7C%203.11%20%7C%203.12-white.svg
# :target: https://www.python.org/downloads/
# ```
# ````{grid} 2 2 2 2
# :::{grid-item}
# **Install it**
#
# ```bash
# conda install -c uibcdf molsysviewer
# ```
# :::
# :::{grid-item}
# **Why MolSysViewer?**
#
# - Anywidget-based, Mol* core
# - Clean Python API
# - Scientific overlays for TopoMT/PharmacophoreMT
# :::
# ````
# :::
#
# ## Use it
#
# ```python
# import molsysviewer as mv
#
# v = mv.MolSysView()
# v.show()
# v.load_pdb_string('...pdb text...')
# v.add_sphere(center=(0, 0, 0), radius=3.0, color=0x00ff00, alpha=0.3)
# ```
#
# Tip: pair this viewer with MolSysMT selections and TopoMT pocket data for rich overlays.

# %% [markdown]
# ## Explore MolSysViewer
#
# ````{grid} 2 2 2 2
# :::{grid-item-card} About
# :link: content/about/index.md
# :columns: 6
# What MolSysViewer is, how to install it, who builds it, and how to cite it.
# :::
# :::{grid-item-card} Showcase
# :link: content/showcase/index.md
# :columns: 6
# Quick demos and notebooks that highlight key workflows.
# :::
# :::{grid-item-card} User Guide
# :link: content/user/index.md
# :columns: 6
# Concepts, tools, and recipes to build scenes, shapes, and overlays.
# :::
# :::{grid-item-card} Developer Guide
# :link: content/developer/index.md
# :columns: 6
# Architecture, contribution flow, testing, and documentation guidance.
# :::
# :::{grid-item-card} API Reference
# :link: api/index.md
# :columns: 6
# Autosummary reference for public modules, classes, and functions.
# :::
# :::{grid-item-card} AI Assistants
# :link: content/ai_assistants.md
# :columns: 6
# Experimental chat helpers tailored to MolSysViewer.
# :::
# ````

# %% [markdown]
# ## Citation
#
# Citation details are coming soon. In the meantime, cite the Mol* engine and the MolSysViewer repository: https://github.com/uibcdf/molsysviewer.

# %% [markdown]
# ```{eval-rst}
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/about/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/showcase/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/user/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/developer/index.md
#    Provisional_Docs_Guidelines.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    api/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/ai_assistants.md
#
# ```
