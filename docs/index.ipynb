# %% [markdown]
# ```{eval-rst}
# :html_theme.sidebar_secondary.remove:
# ```

# %% [markdown]
# :::{figure} _static/logo.svg
# :width: 62%
# :align: center
#
# A Mol*-powered interactive **mol**ecular **sys**tems **viewer** for structural analysis
#
# ```{image} https://img.shields.io/badge/release-0.7.0-white.svg
# :target: https://github.com/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/license-MIT-white.svg
# :target: https://github.com/uibcdf/molsysviewer/blob/master/LICENSE
# ```
# ```{image} https://img.shields.io/badge/install%20with-conda-white.svg
# :target: https://anaconda.org/uibcdf/molsysviewer
# ```
# ```{image} https://img.shields.io/badge/python-3.10%20%7C%203.11%20%7C%203.12-white.svg
# :target: https://www.python.org/downloads/
# ```
# ```{image} https://img.shields.io/badge/DOI-10.5281/zenodo.18072956-white.svg
# :target: https://doi.org/10.5281/zenodo.18072956
# ```
#
# :::
#
# <br/>
#
#
# ## Install it
#
# ```bash
# conda install -c uibcdf molsysviewer
# ```
#
# <br/>
#
# ## Use it

# %%
import molsysviewer as viewer

view = viewer.new_view('181L', selection='molecule_type not in ["water", "ion"]')
view.info(element='molecule')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9ca1">
#   <thead>
#     <tr>
#       <th id="T_c9ca1_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_c9ca1_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_c9ca1_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_c9ca1_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_c9ca1_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_c9ca1_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_c9ca1_level0_col6" class="col_heading level0 col6" >chain index</th>
#       <th id="T_c9ca1_level0_col7" class="col_heading level0 col7" >entity index</th>
#       <th id="T_c9ca1_level0_col8" class="col_heading level0 col8" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c9ca1_row0_col0" class="data row0 col0" >0</td>
# ...

# %%
region_1 = view.new_region('all within 9 angstroms of molecule_name=="BENZENE"', representation='sticks')
view.zoom('molecule_name=="BENZENE"')
view.show()

# %%
from molsysviewer.thirds.jupyter import load_html_in_notebook
load_html_in_notebook('_static/views/181l_benzene.html')
# Out:
#         <iframe
#             width="100%"
#             height="480px"
#             src="_static/views/181l_benzene.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Citation
#
# Citing the [Zenodo DOI of MolSysViewer](https://doi.org/10.5281/zenodo.8092688) in addition to the scientific paper is a way to ensure that others can reproduce your results, as they will know exactly which version of the software you used.
#
# <br/>
#
# ````{tabs}
#
# ```{tab} Paper
#
# Coming soon...
#
# {download}`BibTeX <_static/bibtex/papers.bib>`
#
# ```
# ```{tab} Software
#
# Diego Prada-Gracia & Liliana M. Moreno-Vargas. (2023). uibcdf/MolSysViewer: 0.2.0 (0.2.0). Zenodo. https://doi.org/10.5281/zenodo.8092688
#
# {download}`BibTeX <_static/bibtex/software.bib>`
#
# ```
# ````

# %% [markdown]
# ```{eval-rst}
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/about/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/showcase/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/user/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/developer/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    api/index.md
#
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    content/ai_assistant.md
#
# ```
